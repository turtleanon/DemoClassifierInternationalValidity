# %% [markdown]
# This axillary script was used to identify and consolidate demographic labels for the VinDr dataset

# %%
import pandas as pd
import pydicom as dicom
import os
import cv2
import numpy as np
from PIL import Image, ImageOps
import pylibjpeg

# %%
# Specify the .dcm folder path
folder_path = '/content/s3/VinDR_Full_Dataset'
# Specify the output jpg/png folder path
jpg_folder_path = '/content/VinDr_Full'
train_images_path = os.listdir(os.path.join(folder_path, 'train'))
test_images_path = os.listdir(os.path.join(folder_path, 'test'))
paths = []
sex = []
age = []

# %%
print(len(train_images_path))
print(len(test_images_path))
# Out:
# 15001
# 3001

# %%
for n, image in enumerate(train_images_path):
    ds = dicom.dcmread(os.path.join(folder_path, 'train', image))
    if ds.PhotometricInterpretation == "MONOCHROME2":
        new_image = ds.pixel_array.astype(float)
        scaled_image = (np.maximum(new_image, 0) / new_image.max()) * 255.0
        scaled_image = np.uint8(scaled_image)
        final_image = Image.fromarray(scaled_image)
        image = image.replace('.dicom', '.jpg')
        final_image.save(os.path.join(jpg_folder_path, image))
    else:
        new_image = ds.pixel_array.astype(float)
        scaled_image = (np.maximum(new_image, 0) / new_image.max()) * 255.0
        scaled_image = np.uint8(scaled_image)
        final_image = Image.fromarray(np.uint8() - scaled_image)
        image = image.replace('.dicom', '.jpg')
        final_image.save(os.path.join(jpg_folder_path, image))
    paths.append(image.replace('.dicom', '.jpg'))
    if ds.get('PatientSex') == None:
      sex.append('NaN')
    else:
      sex.append(ds.PatientSex)
    if ds.get('PatientAge') == None:
      age.append('NaN')
    else:
      age.append(ds.PatientAge)
    if n % 50 == 0:
        print('{} image converted'.format(n))

# %%
for n, image in enumerate(test_images_path):
    ds = dicom.dcmread(os.path.join(folder_path, 'test', image))
    if ds.PhotometricInterpretation == "MONOCHROME2":
        new_image = ds.pixel_array.astype(float)
        scaled_image = (np.maximum(new_image, 0) / new_image.max()) * 255.0
        scaled_image = np.uint8(scaled_image)
        final_image = Image.fromarray(scaled_image)
        image = image.replace('.dicom', '.jpg')
        final_image.save(os.path.join(jpg_folder_path, image))
    else:
        new_image = ds.pixel_array.astype(float)
        scaled_image = (np.maximum(new_image, 0) / new_image.max()) * 255.0
        scaled_image = np.uint8(scaled_image)
        final_image = Image.fromarray(np.uint8() - scaled_image)
        image = image.replace('.dicom', '.jpg')
        final_image.save(os.path.join(jpg_folder_path, image))
    paths.append(image.replace('.dicom', '.jpg'))
    if ds.get('PatientSex') == None:
      sex.append('NaN')
    else:
      sex.append(ds.PatientSex)
    if ds.get('PatientAge') == None:
      age.append('NaN')
    else:
      age.append(ds.PatientAge)

    if n % 50 == 0:
        print('{} image converted'.format(n))

# %%
vindr_df= pd.DataFrame(paths, columns = ['Path'])
vindr_df['Sex'] = sex
vindr_df['Age'] = age
vindr_df.to_csv('/content/VinDr_Full/VinDr_labels.csv', index=False)

# %%
df = pd.read_csv('/content/VinDr_Full/VinDr_labels.csv')
df.shape
# Out:
# (18000, 3)
