# %%
import pandas as pd
from fastai.vision.all import *
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !chmod 600 ~/.passwd-s3fs

# %%
# !apt install s3fs
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# s3fs is already the newest version (1.82-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-470
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %%
# !unzip '/s3/CheXpert/CheXpert-v1.0.zip'

# %%
#!pip install wandb
import wandb
wandb.init(project = "CheXpert Gender")
# Out:
# Finishing last run (ID:wh0rdnwr) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# Synced <strong style="color:#cdcd00">deep-galaxy-5</strong>: <a href="https://wandb.ai/pree1199/CheXpert%20Gender/runs/wh0rdnwr" target="_blank">https://wandb.ai/pree1199/CheXpert%20Gender/runs/wh0rdnwr</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221111_151849-wh0rdnwr/logs</code>
# Successfully finished last run (ID:wh0rdnwr). Initializing new run:<br/>
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221111_151902-17esxak9</code>
# Syncing run <strong><a href="https://wandb.ai/pree1199/CheXpert%20Gender/runs/17esxak9" target="_blank">efficient-meadow-6</a></strong> to <a href="https://wandb.ai/pree1199/CheXpert%20Gender" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/pree1199/CheXpert%20Gender/runs/17esxak9?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %% [markdown]
# Training Sex Classification Model with CheXpert

# %%
df = pd.read_csv('/content/chexpert_gender_split.csv')
df['Path'] = df['Path'].str.replace('-small','')

# %%
train_df = df[df.split=='train']
val_df = df[df.split=='val']
test_df = df[df.split=='test']

# %%
train_df.insert(loc = 1, column = 'Valid_Column', value = False)
val_df.insert(loc = 1, column = 'Valid_Column', value = True)
training_df = pd.concat([train_df, val_df])

# %%
import torch; print(torch.cuda.is_available())
# Out:
# True

# %%
path = '/content/'
dls_gender = ImageDataLoaders.from_df(training_df, path, fn_col='Path', label_col='Gender', valid_col = 'Valid_Column', item_tfms=Resize(460), batch_tfms=aug_transforms(size=224), num_workers=4, device=torch.device('cuda'))
learn_gender = vision_learner(dls_gender, resnet34, metrics=accuracy)
learn_gender.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.005248074419796467)

# %%
learn_gender.fine_tune(20, base_lr = 5.2e-3, cbs = [EarlyStoppingCallback(monitor = 'accuracy', min_delta = 0.01, patience = 3), SaveModelCallback(monitor='accuracy', min_delta = 0.01)])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.220844</td>
#       <td>0.162957</td>
#       <td>0.935169</td>
#       <td>1:25:41</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with accuracy value: 0.9351693391799927.
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='6' class='' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       30.00% [6/20 8:26:49<19:42:34]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.112420</td>
#       <td>0.073349</td>
#       <td>0.972085</td>
#       <td>1:25:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.093199</td>
#       <td>0.068650</td>
#       <td>0.974228</td>
#       <td>1:24:41</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.088789</td>
#       <td>0.060513</td>
#       <td>0.977015</td>
#       <td>1:24:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.075834</td>
#       <td>0.049308</td>
#       <td>0.982265</td>
#       <td>1:23:26</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.072560</td>
#       <td>0.039021</td>
#       <td>0.986444</td>
#       <td>1:25:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.060653</td>
#       <td>0.042414</td>
#       <td>0.984837</td>
#       <td>1:24:02</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='1188' class='' max='2093' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       56.76% [1188/2093 42:15<32:11 0.0508]
#     </div>
# Better model found at epoch 0 with accuracy value: 0.9720852971076965.
# Better model found at epoch 3 with accuracy value: 0.9822653532028198.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.112420</td>
#       <td>0.073349</td>
#       <td>0.972085</td>
#       <td>1:25:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.093199</td>
#       <td>0.068650</td>
#       <td>0.974228</td>
#       <td>1:24:41</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.088789</td>
#       <td>0.060513</td>
#       <td>0.977015</td>
#       <td>1:24:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.075834</td>
#       <td>0.049308</td>
#       <td>0.982265</td>
#       <td>1:23:26</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.072560</td>
#       <td>0.039021</td>
#       <td>0.986444</td>
#       <td>1:25:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.060653</td>
#       <td>0.042414</td>
#       <td>0.984837</td>
#       <td>1:24:02</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.049690</td>
#       <td>0.042242</td>
#       <td>0.985534</td>
#       <td>1:24:16</td>
#     </tr>
#   </tbody>
# </table>
# No improvement since epoch 3: early stopping

# %%
learn_gender.export(fname = '/content/sample_data/chexpert_gender.pkl')

# %% [markdown]
# Training Age Classification Model with CheXpert

# %%
df = pd.read_csv('/content/chexpert_age_split.csv')
df['Path'] = df['Path'].str.replace('-small','')
train_df = df[df.split=='train']
val_df = df[df.split=='val']
test_df = df[df.split=='test']
train_df.insert(loc = 1, column = 'Valid_Column', value = False)
val_df.insert(loc = 1, column = 'Valid_Column', value = True)
training_df = pd.concat([train_df, val_df])

# %%
import torch; print(torch.cuda.is_available())
# Out:
# True

# %%
from time import time
import multiprocessing as mp
path = '/content/'
for num_workers in range(2, 20):
  dls_age = ImageDataLoaders.from_df(training_df, path, fn_col='Path', label_col='Patient Age Category', valid_col = 'Valid_Column', item_tfms=Resize(460), batch_tfms=aug_transforms(size=224), num_workers=num_workers, bs=64, device=torch.device('cuda'))
  start = time()
  for epoch in range(1, 3):
      for i, data in enumerate(dls_age, 0):
            pass
      end = time()
  print("Finish with:{} second, num_workers={}".format(end - start, num_workers))
# Out:
# Finish with:1.239776611328125e-05 second, num_workers=2
# Finish with:9.059906005859375e-06 second, num_workers=3
# Finish with:9.5367431640625e-06 second, num_workers=4
# Finish with:1.0251998901367188e-05 second, num_workers=5
# Finish with:9.059906005859375e-06 second, num_workers=6
# Finish with:1.2159347534179688e-05 second, num_workers=7
# Finish with:8.821487426757812e-06 second, num_workers=8
# Finish with:8.821487426757812e-06 second, num_workers=9
# Finish with:1.0967254638671875e-05 second, num_workers=10
# Finish with:9.298324584960938e-06 second, num_workers=11
# Finish with:8.344650268554688e-06 second, num_workers=12
# Finish with:9.059906005859375e-06 second, num_workers=13
# Finish with:9.298324584960938e-06 second, num_workers=14
# Finish with:8.821487426757812e-06 second, num_workers=15
# Finish with:1.1444091796875e-05 second, num_workers=16
# Finish with:8.821487426757812e-06 second, num_workers=17
# Finish with:8.58306884765625e-06 second, num_workers=18
# Finish with:1.0967254638671875e-05 second, num_workers=19

# %%
path = '/content/'
dls_age = ImageDataLoaders.from_df(training_df, path, fn_col='Path', label_col='Patient Age Category', valid_col = 'Valid_Column', item_tfms=Resize(460), batch_tfms=aug_transforms(size=224), num_workers=10, bs=64, device=torch.device('cuda'))
learn_age = vision_learner(dls_age, resnet34, metrics=accuracy)
learn_age.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.0020892962347716093)

# %%
learn_age.fine_tune(40, base_lr = 8e-4, cbs = [EarlyStoppingCallback(monitor = 'accuracy', min_delta = 0.01, patience = 3), SaveModelCallback(monitor='accuracy', min_delta = 0.01)])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.153866</td>
#       <td>1.079073</td>
#       <td>0.507966</td>
#       <td>49:09</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with accuracy value: 0.5079659223556519.
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='5' class='' max='40' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       12.50% [5/40 4:04:24<28:30:54]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.940678</td>
#       <td>0.863204</td>
#       <td>0.614339</td>
#       <td>48:56</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.857197</td>
#       <td>0.809196</td>
#       <td>0.640709</td>
#       <td>49:29</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.801601</td>
#       <td>0.771091</td>
#       <td>0.656435</td>
#       <td>49:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.765204</td>
#       <td>0.772524</td>
#       <td>0.654443</td>
#       <td>49:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.739940</td>
#       <td>0.728554</td>
#       <td>0.675113</td>
#       <td>47:17</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='270' class='' max='1570' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       17.20% [270/1570 07:16<35:01 0.7211]
#     </div>
# Better model found at epoch 0 with accuracy value: 0.6143386960029602.
# Better model found at epoch 1 with accuracy value: 0.6407086849212646.
# Better model found at epoch 2 with accuracy value: 0.6564345359802246.
# Better model found at epoch 4 with accuracy value: 0.675113320350647.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.940678</td>
#       <td>0.863204</td>
#       <td>0.614339</td>
#       <td>48:56</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.857197</td>
#       <td>0.809196</td>
#       <td>0.640709</td>
#       <td>49:29</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.801601</td>
#       <td>0.771091</td>
#       <td>0.656435</td>
#       <td>49:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.765204</td>
#       <td>0.772524</td>
#       <td>0.654443</td>
#       <td>49:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.739940</td>
#       <td>0.728554</td>
#       <td>0.675113</td>
#       <td>47:17</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.725336</td>
#       <td>0.712870</td>
#       <td>0.681088</td>
#       <td>48:56</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.702019</td>
#       <td>0.716151</td>
#       <td>0.682324</td>
#       <td>47:39</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.691772</td>
#       <td>0.704923</td>
#       <td>0.686307</td>
#       <td>47:36</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.657712</td>
#       <td>0.696510</td>
#       <td>0.689946</td>
#       <td>47:26</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.647966</td>
#       <td>0.699116</td>
#       <td>0.693861</td>
#       <td>47:22</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.617965</td>
#       <td>0.737990</td>
#       <td>0.684109</td>
#       <td>46:48</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 7 with accuracy value: 0.6863068342208862.
# No improvement since epoch 7: early stopping

# %%
learn_age.export(fname = '/content/sample_data/chexpert_age.pkl')

# %% [markdown]
# Training Race v2 with CheXpert

# %%
df = pd.read_csv('/content/chexpert_race_v2_split.csv')
df['Path'] = df['Path'].str.replace('-small','')
train_df = df[df.split=='train']
val_df = df[df.split=='val']
test_df = df[df.split=='test']
train_df.insert(loc = 1, column = 'Valid_Column', value = False)
val_df.insert(loc = 1, column = 'Valid_Column', value = True)
training_df = pd.concat([train_df, val_df])

# %%
import torch; print(torch.cuda.is_available())
# Out:
# True

# %%
from time import time
import multiprocessing as mp
path = '/content/'
for num_workers in range(2, 20):
  dls_race = ImageDataLoaders.from_df(training_df, path, fn_col='Path', label_col='Race/Ethnicity', valid_col = 'Valid_Column', item_tfms=Resize(460), batch_tfms=aug_transforms(size=224), num_workers=num_workers, bs=64, device=torch.device('cuda'))
  start = time()
  for epoch in range(1, 3):
      for i, data in enumerate(dls_race, 0):
            pass
      end = time()
  print("Finish with:{} second, num_workers={}".format(end - start, num_workers))
# Out:
# Finish with:8.821487426757812e-06 second, num_workers=2
# Finish with:9.5367431640625e-06 second, num_workers=3
# Finish with:1.0728836059570312e-05 second, num_workers=4
# Finish with:8.821487426757812e-06 second, num_workers=5
# Finish with:1.8835067749023438e-05 second, num_workers=6
# Finish with:1.1444091796875e-05 second, num_workers=7
# Finish with:1.0251998901367188e-05 second, num_workers=8
# Finish with:9.775161743164062e-06 second, num_workers=9
# Finish with:8.821487426757812e-06 second, num_workers=10
# Finish with:8.58306884765625e-06 second, num_workers=11
# Finish with:1.0728836059570312e-05 second, num_workers=12
# Finish with:8.58306884765625e-06 second, num_workers=13
# Finish with:8.344650268554688e-06 second, num_workers=14
# Finish with:1.1205673217773438e-05 second, num_workers=15
# Finish with:1.0251998901367188e-05 second, num_workers=16
# Finish with:8.821487426757812e-06 second, num_workers=17
# Finish with:9.298324584960938e-06 second, num_workers=18
# Finish with:9.5367431640625e-06 second, num_workers=19
# Finish with:1.0013580322265625e-05 second, num_workers=19
# Finish with:1.1682510375976562e-05 second, num_workers=19
# Finish with:9.5367431640625e-06 second, num_workers=19
# Finish with:8.821487426757812e-06 second, num_workers=19
# Finish with:8.821487426757812e-06 second, num_workers=19

# %%
path = '/content/'
dls_race2 = ImageDataLoaders.from_df(training_df, path, fn_col='Path', label_col='Race/Ethnicity', valid_col = 'Valid_Column', item_tfms=Resize(460), batch_tfms=aug_transforms(size=224), num_workers=11, bs=64, device=torch.device('cuda'))
learn_race2 = vision_learner(dls_race2, resnet34, metrics=accuracy)
learn_race2.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.0030199517495930195)

# %%
learn_race2.fine_tune(40, base_lr = 3e-3, cbs = [EarlyStoppingCallback(monitor = 'accuracy', min_delta = 0.01, patience = 3), SaveModelCallback(monitor='accuracy', min_delta = 0.01)])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.945320</td>
#       <td>0.902977</td>
#       <td>0.660825</td>
#       <td>50:36</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with accuracy value: 0.6608245372772217.
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.733137</td>
#       <td>0.686765</td>
#       <td>0.741685</td>
#       <td>49:41</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.660089</td>
#       <td>0.648795</td>
#       <td>0.760008</td>
#       <td>49:37</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.619987</td>
#       <td>0.630633</td>
#       <td>0.770829</td>
#       <td>51:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.607602</td>
#       <td>0.604934</td>
#       <td>0.776804</td>
#       <td>50:43</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.571759</td>
#       <td>0.597185</td>
#       <td>0.779592</td>
#       <td>50:31</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.547664</td>
#       <td>0.583080</td>
#       <td>0.795061</td>
#       <td>50:23</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.539954</td>
#       <td>0.621190</td>
#       <td>0.769966</td>
#       <td>50:36</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.512228</td>
#       <td>0.617077</td>
#       <td>0.778995</td>
#       <td>51:04</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.516826</td>
#       <td>0.557934</td>
#       <td>0.797384</td>
#       <td>51:03</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with accuracy value: 0.7416849136352539.
# Better model found at epoch 1 with accuracy value: 0.7600079774856567.
# Better model found at epoch 2 with accuracy value: 0.7708292007446289.
# Better model found at epoch 5 with accuracy value: 0.7950607538223267.
# No improvement since epoch 5: early stopping

# %%
learn_race2.export(fname = '/content/sample_data/chexpert_race2.pkl')
