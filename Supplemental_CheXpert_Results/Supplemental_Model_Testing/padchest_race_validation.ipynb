# %%
# !chmod 600 ~/.passwd-s3fs

# %%
# !apt install s3fs

# %%
# !mkdir /content/s3
# !s3fs um2ii-datasets /content/s3

# %%
import pandas as pd
from fastai.vision.all import *
from sklearn.model_selection import train_test_split
import os
from glob import glob
from sklearn import metrics

# %% [markdown]
# CheXpert Race v1 Validation

# %%
test_df = pd.read_csv('/content/s3/PadChest_Full_Dataset/Docs/PADCHEST_chest_x_ray_images_labels_160K_01.02.19.csv')
test_df['Path'] = 's3/PadChest_Full_Dataset/' + test_df['ImageDir'].astype(str) + '/' + test_df['ImageID'].astype(str)
#Isolate only frontal view CXRs
print(test_df['Projection'].unique())
ap_df = test_df[test_df['Projection']=='AP']
pa_df = test_df[test_df['Projection']=='PA']
ap_hor_df = test_df[test_df['Projection']=='AP_horizontal']
test_df = pd.concat([ap_df, pa_df, ap_hor_df], ignore_index=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (4,19,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ['AP' 'AP_horizontal' 'COSTAL' 'EXCLUDE' 'L' 'PA']

# %%
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/42/216840111366964013076187734852011291090445391_00-196-188.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/44/216840111366964012373310883942009170084120009_00-097-074.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/44/216840111366964012373310883942009180082307973_00-097-011.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/48/216840111366964012819207061112010306085429121_04-020-102.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/16/216840111366964013649110343042013092101343018_02-075-146.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/17/216840111366964013590140476722013049100117076_02-063-097.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/42/216840111366964012373310883942009117084022290_00-064-025.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/43/216840111366964012283393834152009033140208626_00-059-118.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/43/216840111366964012283393834152009033102258826_00-059-087.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/49/216840111366964012819207061112010315104455352_04-024-184.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/13/216840111366964013686042548532013208193054515_02-026-007.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/13/216840111366964013590140476722013058110301622_02-056-111.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/17/216840111366964013590140476722013043111952381_02-065-198.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/19/216840111366964013829543166512013353113303615_02-092-190.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/20/216840111366964013962490064942014134093945580_01-178-104.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/41/216840111366964012989926673512011151082430686_00-157-045.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/43/216840111366964012339356563862009072111404053_00-043-192.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/43/216840111366964012487858717522009280135853083_00-075-001.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/44/216840111366964012819207061112010281134410801_00-129-131.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/46/216840111366964012989926673512011074122523403_00-163-058.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/46/216840111366964012558082906712009327122220177_00-102-064.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/46/216840111366964012373310883942009152114636712_00-102-045.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/46/216840111366964012989926673512011083134050913_00-168-009.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/47/216840111366964012959786098432011033083840143_00-176-115.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/49/216840111366964012819207061112010307142602253_04-014-084.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/18/216840111366964013590140476722013028161046120_02-015-149.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/41/216840111366964012989926673512011132200139442_00-157-099.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/43/216840111366964012989926673512011101154138555_00-191-086.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/43/216840111366964012558082906712009301143450268_00-075-157.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/45/216840111366964012339356563862009068084200743_00-045-105.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/45/216840111366964012558082906712009300162151055_00-078-079.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/47/216840111366964013076187734852011178154626671_00-145-086.png']
test_df = test_df.loc[test_df['Path'] != 's3/PadChest_Full_Dataset/48/216840111366964013076187734852011287092959219_00-195-171.png']
test_df.shape
# Out:
# (110614, 37)

# %%
chexpert_race1_model = load_learner('/content/chexpert_race1.pkl')
chexpert_race1_model.dls.to(device='cuda')
chexpert_race1_model.model.to(device='cuda')
race_test_dl = chexpert_race1_model.dls.test_dl(test_df)
race_preds = chexpert_race1_model.get_preds(dl=race_test_dl, with_decoded=True)
print(chexpert_race1_model.dls.vocab)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ['Non-Hispanic Asian', 'Non-Hispanic Black', 'Non-Hispanic White']

# %%
race_labels = chexpert_race1_model.dls.vocab.o2i.keys()
prediction_counts = [race_preds[2].tolist().count(0), race_preds[2].tolist().count(1), race_preds[2].tolist().count(2)]
plt.bar(race_labels, prediction_counts, color ='blue',
        width = 0.4)
# Out:
# <BarContainer object of 3 artists>

# %%
test_df.insert(len(test_df.columns), 'Race/Ethnicity_Tensor_Id', race_preds[2].numpy())
test_df.insert(len(test_df.columns), 'Race/Ethnicity_Probability', race_preds[0].numpy().tolist())
print(test_df)
test_df.to_csv('/content/sample_data/chexpert_race1_padchest_test.csv')
# Out:
#         Unnamed: 0  \
# 0                0
# 1                1
# 2                2
# 3                3
# 4                4
# ...            ...
# 110609       18900
# 110610       18901
# 110611       18902
# 110612       18903
# 110613       18904
#
#                                                                    ImageID  \
# 0                       313903302629300007485735352869488750471_75sg0k.png
# 1                       172548964592157267755522496623963445785_3moi59.png
# 2                       144238093861007575291420728879881361908_ajle4j.png
# 3                        36034963984131922178434446816145605448_3lh821.png
# 4                       155848149910446291725998642481087011204_ycbfzg.png
# ...                                                                    ...
# 110609        216840111366964012819207061112010320125255984_04-013-018.png
# 110610        216840111366964012819207061112010320084826641_04-013-131.png
# 110611        216840111366964012904401302362010328124037536_04-013-133.png
# 110612        216840111366964012904401302362010328091616774_04-013-169.png
# 110613  128401136192941452208639063169675154235144414529368_00-184-186.png
#
#         ImageDir  StudyDate_DICOM                StudyID     PatientID  \
# 0              0         20170125    3.139033026293E+038  3.707275e+36
# 1              0         20170126  1.72548964592157E+038  5.730059e+37
# 2              0         20161214  1.44238093861008E+038  2.206510e+38
# 3              0         20160809  3.60349639841319E+037  6.783719e+37
# 4              0         20160108  1.55848149910446E+038  1.590406e+38
# ...          ...              ...                    ...           ...
# 110609        49         20101116  2.16840111366964E+044  7.208545e+37
# 110610        49         20101116  2.16840111366964E+044  4.177175e+37
# 110611        49         20101124  2.16840111366964E+044  1.526248e+38
# 110612        49         20101124  2.16840111366964E+044  2.385737e+38
# 110613        49         20110415  1.28401136192941E+050  5.264874e+37
#
#         PatientBirth PatientSex_DICOM ViewPosition_DICOM     Projection  ...  \
# 0             1978.0                M                NaN             AP  ...
# 1             1930.0                M                 AP             AP  ...
# 2             2012.0                F                NaN             AP  ...
# 3             2016.0                F                 AP             AP  ...
# 4             1929.0                F                NaN             AP  ...
# ...              ...              ...                ...            ...  ...
# 110609        1925.0                F                NaN  AP_horizontal  ...
# 110610        1973.0                M                NaN  AP_horizontal  ...
# 110611        1959.0                F                NaN  AP_horizontal  ...
# 110612        1932.0                F                NaN  AP_horizontal  ...
# 110613        1965.0                M                NaN  AP_horizontal  ...
#
#                                                                                                                                                                                                                Report  \
# 0        objet mejori radiolog con practic resolucion infiltr intersticioalveol objetiv estudi previ fech 04 01 2017 persist algun opac mal defin bas izquierd . rest estudi sin cambi relev respect previ con comp .
# 1               imagen aument densid pseudonodul nivel basal derech izquierd sugest primer posibil diagnost dad no estudi previ dia 29 11 16 proces infecci inflamatori men probabl parec afectacion metastas primari
# 2                                                                                                                                             minim infiltr infrahili derech si clinic compat proces neumon infecci .
# 3                                                                                                                       siluet cardiac aument taman favorec proyeccion anter posterior . hili prominent orig vascul .
# 4                                                                                                                          sond nasogastr infradiafragmat . estudi suboptim con artefact proyect hemitorax izquierd .
# ...                                                                                                                                                                                                               ...
# 110609                                                                                                                         cardiomegali . cambi parenquimat pulmonar caract cronic . no apreci condens pulmonar .
# 110610                                                              condensacion parenquimat l hemitorax izquierd are mayor densid lsd lid . desconozc dat clinic pacient . probabl discret derram pleural izquierd .
# 110611                                                                                                                    control colocacion reservori subcutane con extrem distal porcion craneal ven cav superior .
# 110612                                                                                                  canul traqueostomi . sond nasogastr infradiafragmat camp radiolog explor . aument densid inici atelectasi lid
# 110613                                                                                                                                              tub endotraqueal sond nasogastr situacion correct . sin hallazg .
#
#        MethodLabel                                                     Labels  \
# 0        Physician  ['unchanged', 'alveolar pattern', 'interstitial pattern']
# 1        Physician                              ['pseudonodule', 'pneumonia']
# 2        Physician                               ['pneumonia', 'infiltrates']
# 3        Physician             ['cardiomegaly', 'vascular hilar enlargement']
# 4        Physician                           ['NSG tube', 'suboptimal study']
# ...            ...                                                        ...
# 110609   RNN_model                        ['cardiomegaly', 'chronic changes']
# 110610   RNN_model                      ['consolidation', 'pleural effusion']
# 110611   RNN_model                      ['reservoir central venous catheter']
# 110612   RNN_model                      ['tracheostomy tube', 'NSG tube', '']
# 110613   RNN_model                         ['NSG tube', ' endotracheal tube']
#
#                                                                                         Localizations  \
# 0                                                                           ['loc basal', 'loc left']
# 1                                                              ['loc basal', 'loc right', 'loc left']
# 2                                                                     ['loc infrahilar', 'loc right']
# 3                                                                        ['loc hilar', 'loc cardiac']
# 4                                                ['loc infradiaphragm', 'loc hemithorax', 'loc left']
# ...                                                                                               ...
# 110609                                                                                ['loc cardiac']
# 110610  ['loc left', 'loc pleural', 'loc right lower lobe', 'loc hemithorax', 'loc right upper lobe']
# 110611                                                 ['loc subcutaneous', 'loc superior cave vein']
# 110612                                 ['loc right lower lobe', 'loc infradiaphragm', 'loc tracheal']
# 110613                                                                               ['loc tracheal']
#
#                                                                                                                                     LabelsLocalizationsBySentence  \
# 0                                                                          [['unchanged'], ['alveolar pattern', 'interstitial pattern', 'loc basal', 'loc left']]
# 1                                                                                           [['pseudonodule', 'pneumonia', 'loc basal', 'loc right', 'loc left']]
# 2                                                                                                   [['pneumonia', 'infiltrates', 'loc infrahilar', 'loc right']]
# 3                                                 [['cardiomegaly', 'loc cardiac'], ['cardiomegaly', 'loc cardiac'], ['vascular hilar enlargement', 'loc hilar']]
# 4                                                                        [['NSG tube', 'loc infradiaphragm'], ['suboptimal study', 'loc hemithorax', 'loc left']]
# ...                                                                                                                                                           ...
# 110609                                                                                               ['cardiomegaly', 'loc cardiac', 'chronic changes', 'normal']
# 110610  ['consolidation', 'loc right lower lobe', 'loc right upper lobe', 'loc hemithorax', 'loc left', 'exclude', 'pleural effusion', 'loc left', 'loc pleural']
# 110611                                                                        ['reservoir central venous catheter', 'loc superior cave vein', 'loc subcutaneous']
# 110612                                                        ['tracheostomy tube', 'loc tracheal', 'NSG tube', 'loc infradiaphragm', '', 'loc right lower lobe']
# 110613                                                                                               ['NSG tube', ' endotracheal tube', 'loc tracheal', 'normal']
#
#                       labelCUIS  \
# 0       ['C1332240' 'C2073538']
# 1                  ['C0032285']
# 2       ['C0032285' 'C0277877']
# 3                  ['C0018800']
# 4                  ['C2828075']
# ...                         ...
# 110609  ['C0018800' 'C0742362']
# 110610  ['C0521530' 'C2073625']
# 110611             ['C2026143']
# 110612          ['C0184159' '']
# 110613             ['C0336630']
#
#                                                LocalizationsCUIS  \
# 0                                        ['C1282378' 'C0443246']
# 1                             ['C1282378' 'C0444532' 'C0443246']
# 2                                                   ['C0444532']
# 3                                        ['C0205150' 'C1522601']
# 4                                        ['C0934569' 'C0443246']
# ...                                                          ...
# 110609                                              ['C1522601']
# 110610  ['C0443246' 'C0032225' 'C1261075' 'C0934569' 'C1261074']
# 110611                                   ['C0443315' 'C3165182']
# 110612                                   ['C1261075' 'C0040578']
# 110613                                              ['C0040578']
#
#                                                                                                   Path  \
# 0                        s3/PadChest_Full_Dataset/0/313903302629300007485735352869488750471_75sg0k.png
# 1                        s3/PadChest_Full_Dataset/0/172548964592157267755522496623963445785_3moi59.png
# 2                        s3/PadChest_Full_Dataset/0/144238093861007575291420728879881361908_ajle4j.png
# 3                         s3/PadChest_Full_Dataset/0/36034963984131922178434446816145605448_3lh821.png
# 4                        s3/PadChest_Full_Dataset/0/155848149910446291725998642481087011204_ycbfzg.png
# ...                                                                                                ...
# 110609        s3/PadChest_Full_Dataset/49/216840111366964012819207061112010320125255984_04-013-018.png
# 110610        s3/PadChest_Full_Dataset/49/216840111366964012819207061112010320084826641_04-013-131.png
# 110611        s3/PadChest_Full_Dataset/49/216840111366964012904401302362010328124037536_04-013-133.png
# 110612        s3/PadChest_Full_Dataset/49/216840111366964012904401302362010328091616774_04-013-169.png
# 110613  s3/PadChest_Full_Dataset/49/128401136192941452208639063169675154235144414529368_00-184-186.png
#
#         Race/Ethnicity_Tensor_Id  \
# 0                              2
# 1                              2
# 2                              2
# 3                              2
# 4                              2
# ...                          ...
# 110609                         2
# 110610                         2
# 110611                         2
# 110612                         2
# 110613                         2
#
#                                             Race/Ethnicity_Probability
# 0         [0.16293101012706757, 0.310441255569458, 0.5266277194023132]
# 1       [0.21858973801136017, 0.22167322039604187, 0.5597370862960815]
# 2        [0.20160876214504242, 0.2678552567958832, 0.5305359959602356]
# 3        [0.15470044314861298, 0.21568714082241058, 0.629612386226654]
# 4       [0.13422954082489014, 0.38541850447654724, 0.4803519546985626]
# ...                                                                ...
# 110609  [0.13776923716068268, 0.32111474871635437, 0.5411160588264465]
# 110610  [0.12826178967952728, 0.3857778310775757, 0.48596030473709106]
# 110611   [0.13596147298812866, 0.2899662256240845, 0.5740722417831421]
# 110612    [0.128594771027565, 0.38192760944366455, 0.4894776940345764]
# 110613   [0.13402847945690155, 0.3552185297012329, 0.5107530355453491]
#
# [110614 rows x 39 columns]
